# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def data_load():
    response_file_path = '/content/drive/MyDrive/Sparse_PUFs/train_responses.dat'
    challenge_file_path = '/content/drive/MyDrive/Sparse_PUFs/train_challenges.dat'
    response_file = open(response_file_path, "r")
    response_data = list(response_file.read().split("\n"))
    response_values = []
    for value in response_data:
        if value:
            x = float(value)
            response_values.append(x)

    challenge_file = open(challenge_file_path, "r")
    challenge_data = list(challenge_file.read().split("\n"))
    challenge_values = []
    for line in challenge_data:
        challenge_line = []
        if line:
            parts = line.split(" ")
            for part in parts:
                if part.isdigit():
                    challenge_line.append(part)
        else:
            continue
        challenge_values.append(challenge_line)

    return np.asarray(challenge_values, dtype=float), np.asarray(response_values)

# %%
challenges, responses = data_load()
responses
# Out:
# array([1852.119682, 2103.222591, 2121.447663, ..., 2026.056949,
#        2100.444096, 1988.291136])

# %%
def train_test_split(data, targets, test_size, random_state=None):
    np.random.seed(random_state)
    num_samples = len(data)
    num_test_samples = int(num_samples * test_size)
    shuffled_indices = np.random.permutation(num_samples)

    train_indices = shuffled_indices[:-num_test_samples]
    test_indices = shuffled_indices[-num_test_samples:]

    X_train = data[train_indices]
    y_train = targets[train_indices]
    X_test = data[test_indices]
    y_test = targets[test_indices]

    return X_train, X_test, y_train, y_test

# %%
# Perform dataset splitting, e.g., using train-test split
X_train, X_val, y_train, y_val = train_test_split(challenges, responses, test_size=0.2, random_state=None)
y_train.shape
# Out:
# (1280,)

# %%
def compute_rho_j(X, y, w, j):
    X_k = np.delete(X, j, axis=1)  # Remove the j variable i.e., j column
    w_k = np.delete(w, j)  # Remove the weight j
    predict = np.matmul(X_k, w_k.T)
    residual = y - predict  # Calculate residual as y - predict
    X_j = X[:, j]  # m*1 vector
    rho_j = np.dot(X_j, residual)
    return rho_j

# %%
#z computation for unnormalised features
def compute_z_j(X,j):
  X_j=X[:,j]
  z_j = np.dot(X_j,X_j) #Compute sum for each column
  return(z_j)

# %%
def cost_function_ols(X, w, y):
    n = y.size
    y_pred = np.matmul(X, w.T)
    error = y_pred - y
    cost = 0.5 * np.dot(error, error.T) / n
    return cost

# %%
def plot_cost_iter(cost_array):
  iters=cost_array.keys()
  cost=cost_array.values()
  fig=sns.scatterplot(x=iters,y=cost)
  fig.set_xlabel('iters')
  fig.set_ylabel('cost')
  return fig

# %%
def soft_thresholding(x, threshold):
    return np.sign(x) * np.maximum(np.abs(x) - threshold, 0)

# %%
def r_squared(y_true, y_pred):
    y_mean = np.mean(y_true)
    ss_total = np.sum((y_true - y_mean) ** 2)
    ss_residual = np.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_residual / ss_total)
    return r2

# %%
# Define the tolerance
tolerance = 0.0001

# Initialize Theta Values to 0
w = np.zeros(X_train.shape[1], dtype=float)

# Load weights from the text file
weights_file = '/content/drive/MyDrive/Sparse_PUFs/CD_initial_weights.txt'

try:
    with open(weights_file, "r") as file:
        weights = [float(line.strip()) for line in file.readlines()]
        # Check if the number of weights matches the shape of w
        if len(weights) != len(w):
            print("Number of weights in the file does not match the shape of w.")
        else:
            w = np.array(weights)
            print("Weights loaded successfully from", weights_file)
except FileNotFoundError:
    print("Weights file not found. Initializing weights to zeros.")

print("Initial weights:")
print(w)
# Out:
# Weights loaded successfully from /content/drive/MyDrive/Sparse_PUFs/CD_initial_weights.txt
# Initial weights:
# [-0.02460093 -0.05127718 -0.08050143 ...  9.25387199  0.60891573
#  -0.01967851]

# %%
def coordinate_descent_ols(y, X, w, tolerance):
    max_iteration = 200
    iteration = 0
    N, d = X.shape
    cost_diff = 1
    cost_array = {}
    while cost_diff > tolerance and iteration < max_iteration:
        iteration += 1
        cost_old = cost_function_ols(X, w, y)

        for j in range(d):
            rho_j = compute_rho_j(X, y, w, j)
            z_j = compute_z_j(X, j)
            w[j] = rho_j / z_j
            if w[j] < 0:
                w[j] = 0

        # Update the cost function
        cost_new = cost_function_ols(X, w, y)
        cost_array[iteration] = cost_new
        cost_diff = abs(cost_new - cost_old)

        # Calculate MAPE, MSE, and MAE
        predictions = np.dot(X, w)
        mape = np.mean(np.abs((y - predictions) / y)) * 100
        mse = np.mean((y - predictions) ** 2)
        mae = np.mean(np.abs(y - predictions))

        # Print MAPE, MSE, MAE, error, and iteration number
        print(f"Iteration {iteration} - MAPE: {mape:.2f}%, MSE: {mse:.4f}, MAE: {mae:.4f}")

    print(w)
    return w, iteration, cost_array

# %%
# run the coordinate descent for our train set
w_cd_ols,iter_ols,cost_array_ols=coordinate_descent_ols(y_train,X_train,w,tolerance)
output_path = '/content/drive/MyDrive/Sparse_PUFs/CD_final_weights.txt'
np.savetxt(output_path, w_cd_ols)

print(f"Weights saved to {output_path}")
# display
fig_ols=plot_cost_iter(cost_array_ols)
fig_ols
# Out:
# Iteration 1 - MAPE: 0.52%, MSE: 163.6631, MAE: 10.5173
# Iteration 2 - MAPE: 0.38%, MSE: 90.4614, MAE: 7.6022
# Iteration 3 - MAPE: 0.32%, MSE: 64.9599, MAE: 6.3863
# Iteration 4 - MAPE: 0.28%, MSE: 51.5868, MAE: 5.6775
# Iteration 5 - MAPE: 0.26%, MSE: 43.2083, MAE: 5.1934
# Iteration 6 - MAPE: 0.24%, MSE: 37.4997, MAE: 4.8325
# Iteration 7 - MAPE: 0.23%, MSE: 33.3443, MAE: 4.5490
# Iteration 8 - MAPE: 0.21%, MSE: 30.1583, MAE: 4.3276
# Iteration 9 - MAPE: 0.21%, MSE: 27.6680, MAE: 4.1462
# Iteration 10 - MAPE: 0.20%, MSE: 25.6557, MAE: 3.9892
# Iteration 11 - MAPE: 0.19%, MSE: 23.9877, MAE: 3.8575
# Iteration 12 - MAPE: 0.19%, MSE: 22.5789, MAE: 3.7508
# Iteration 13 - MAPE: 0.18%, MSE: 21.3794, MAE: 3.6627
# Iteration 14 - MAPE: 0.18%, MSE: 20.3290, MAE: 3.5839
# Iteration 15 - MAPE: 0.17%, MSE: 19.3965, MAE: 3.5091
# Iteration 16 - MAPE: 0.17%, MSE: 18.5760, MAE: 3.4414
# Iteration 17 - MAPE: 0.17%, MSE: 17.8471, MAE: 3.3801
# Iteration 18 - MAPE: 0.16%, MSE: 17.1976, MAE: 3.3205
# Iteration 19 - MAPE: 0.16%, MSE: 16.6243, MAE: 3.2642
# Iteration 20 - MAPE: 0.16%, MSE: 16.1070, MAE: 3.2089
# Iteration 21 - MAPE: 0.16%, MSE: 15.6222, MAE: 3.1553
# Iteration 22 - MAPE: 0.15%, MSE: 15.1861, MAE: 3.1052
# Iteration 23 - MAPE: 0.15%, MSE: 14.7902, MAE: 3.0565
# Iteration 24 - MAPE: 0.15%, MSE: 14.4265, MAE: 3.0102
# Iteration 25 - MAPE: 0.15%, MSE: 14.0912, MAE: 2.9701
# Iteration 26 - MAPE: 0.15%, MSE: 13.7799, MAE: 2.9332
# Iteration 27 - MAPE: 0.14%, MSE: 13.4899, MAE: 2.8980
# Iteration 28 - MAPE: 0.14%, MSE: 13.2177, MAE: 2.8646
# Iteration 29 - MAPE: 0.14%, MSE: 12.9611, MAE: 2.8343
# Iteration 30 - MAPE: 0.14%, MSE: 12.7168, MAE: 2.8075
# Iteration 31 - MAPE: 0.14%, MSE: 12.4846, MAE: 2.7813
# Iteration 32 - MAPE: 0.14%, MSE: 12.2657, MAE: 2.7571
# Iteration 33 - MAPE: 0.14%, MSE: 12.0587, MAE: 2.7342
# Iteration 34 - MAPE: 0.13%, MSE: 11.8621, MAE: 2.7126
# Iteration 35 - MAPE: 0.13%, MSE: 11.6752, MAE: 2.6924
# Iteration 36 - MAPE: 0.13%, MSE: 11.4963, MAE: 2.6731
# Iteration 37 - MAPE: 0.13%, MSE: 11.3237, MAE: 2.6528
# Iteration 38 - MAPE: 0.13%, MSE: 11.1573, MAE: 2.6345
# Iteration 39 - MAPE: 0.13%, MSE: 10.9957, MAE: 2.6162
# Iteration 40 - MAPE: 0.13%, MSE: 10.8391, MAE: 2.5997
# Iteration 41 - MAPE: 0.13%, MSE: 10.6863, MAE: 2.5833
# Iteration 42 - MAPE: 0.13%, MSE: 10.5382, MAE: 2.5687
# Iteration 43 - MAPE: 0.13%, MSE: 10.3955, MAE: 2.5550
# Iteration 44 - MAPE: 0.13%, MSE: 10.2584, MAE: 2.5420
# Iteration 45 - MAPE: 0.13%, MSE: 10.1282, MAE: 2.5290
# Iteration 46 - MAPE: 0.12%, MSE: 10.0032, MAE: 2.5155
# Iteration 47 - MAPE: 0.12%, MSE: 9.8826, MAE: 2.5015
# Iteration 48 - MAPE: 0.12%, MSE: 9.7664, MAE: 2.4873
# Iteration 49 - MAPE: 0.12%, MSE: 9.6546, MAE: 2.4732
# Iteration 50 - MAPE: 0.12%, MSE: 9.5463, MAE: 2.4593
# Iteration 51 - MAPE: 0.12%, MSE: 9.4418, MAE: 2.4457
# Iteration 52 - MAPE: 0.12%, MSE: 9.3404, MAE: 2.4320
# Iteration 53 - MAPE: 0.12%, MSE: 9.2413, MAE: 2.4188
# Iteration 54 - MAPE: 0.12%, MSE: 9.1458, MAE: 2.4071
# Iteration 55 - MAPE: 0.12%, MSE: 9.0546, MAE: 2.3965
# Iteration 56 - MAPE: 0.12%, MSE: 8.9662, MAE: 2.3862
# Iteration 57 - MAPE: 0.12%, MSE: 8.8807, MAE: 2.3752
# Iteration 58 - MAPE: 0.12%, MSE: 8.7985, MAE: 2.3645
# Iteration 59 - MAPE: 0.12%, MSE: 8.7198, MAE: 2.3537
# Iteration 60 - MAPE: 0.12%, MSE: 8.6444, MAE: 2.3426
# Iteration 61 - MAPE: 0.12%, MSE: 8.5715, MAE: 2.3319
# Iteration 62 - MAPE: 0.12%, MSE: 8.5016, MAE: 2.3223
# Iteration 63 - MAPE: 0.11%, MSE: 8.4344, MAE: 2.3129
# Iteration 64 - MAPE: 0.11%, MSE: 8.3689, MAE: 2.3035
# Iteration 65 - MAPE: 0.11%, MSE: 8.3052, MAE: 2.2945
# Iteration 66 - MAPE: 0.11%, MSE: 8.2433, MAE: 2.2866
# Iteration 67 - MAPE: 0.11%, MSE: 8.1831, MAE: 2.2794
# Iteration 68 - MAPE: 0.11%, MSE: 8.1241, MAE: 2.2717
# Iteration 69 - MAPE: 0.11%, MSE: 8.0662, MAE: 2.2639
# Iteration 70 - MAPE: 0.11%, MSE: 8.0097, MAE: 2.2556
# Iteration 71 - MAPE: 0.11%, MSE: 7.9541, MAE: 2.2473
# Iteration 72 - MAPE: 0.11%, MSE: 7.8994, MAE: 2.2391
# Iteration 73 - MAPE: 0.11%, MSE: 7.8453, MAE: 2.2315
# Iteration 74 - MAPE: 0.11%, MSE: 7.7918, MAE: 2.2236
# Iteration 75 - MAPE: 0.11%, MSE: 7.7390, MAE: 2.2155
# Iteration 76 - MAPE: 0.11%, MSE: 7.6868, MAE: 2.2071
# Iteration 77 - MAPE: 0.11%, MSE: 7.6354, MAE: 2.1987
# Iteration 78 - MAPE: 0.11%, MSE: 7.5851, MAE: 2.1905
# Iteration 79 - MAPE: 0.11%, MSE: 7.5358, MAE: 2.1816
# Iteration 80 - MAPE: 0.11%, MSE: 7.4878, MAE: 2.1727
# Iteration 81 - MAPE: 0.11%, MSE: 7.4412, MAE: 2.1645
# Iteration 82 - MAPE: 0.11%, MSE: 7.3953, MAE: 2.1564
# Iteration 83 - MAPE: 0.11%, MSE: 7.3500, MAE: 2.1485
# Iteration 84 - MAPE: 0.11%, MSE: 7.3056, MAE: 2.1407
# Iteration 85 - MAPE: 0.11%, MSE: 7.2623, MAE: 2.1333
# Iteration 86 - MAPE: 0.11%, MSE: 7.2198, MAE: 2.1253
# Iteration 87 - MAPE: 0.10%, MSE: 7.1781, MAE: 2.1179
# Iteration 88 - MAPE: 0.10%, MSE: 7.1372, MAE: 2.1108
# Iteration 89 - MAPE: 0.10%, MSE: 7.0968, MAE: 2.1042
# Iteration 90 - MAPE: 0.10%, MSE: 7.0571, MAE: 2.0980
# Iteration 91 - MAPE: 0.10%, MSE: 7.0183, MAE: 2.0921
# Iteration 92 - MAPE: 0.10%, MSE: 6.9800, MAE: 2.0861
# Iteration 93 - MAPE: 0.10%, MSE: 6.9419, MAE: 2.0803
# Iteration 94 - MAPE: 0.10%, MSE: 6.9039, MAE: 2.0746
# Iteration 95 - MAPE: 0.10%, MSE: 6.8663, MAE: 2.0689
# Iteration 96 - MAPE: 0.10%, MSE: 6.8292, MAE: 2.0635
# Iteration 97 - MAPE: 0.10%, MSE: 6.7926, MAE: 2.0582
# Iteration 98 - MAPE: 0.10%, MSE: 6.7565, MAE: 2.0526
# Iteration 99 - MAPE: 0.10%, MSE: 6.7210, MAE: 2.0470
# Iteration 100 - MAPE: 0.10%, MSE: 6.6860, MAE: 2.0418
# Iteration 101 - MAPE: 0.10%, MSE: 6.6515, MAE: 2.0366
# Iteration 102 - MAPE: 0.10%, MSE: 6.6173, MAE: 2.0314
# Iteration 103 - MAPE: 0.10%, MSE: 6.5836, MAE: 2.0266
# Iteration 104 - MAPE: 0.10%, MSE: 6.5502, MAE: 2.0219
# Iteration 105 - MAPE: 0.10%, MSE: 6.5173, MAE: 2.0174
# Iteration 106 - MAPE: 0.10%, MSE: 6.4846, MAE: 2.0126
# Iteration 107 - MAPE: 0.10%, MSE: 6.4522, MAE: 2.0075
# Iteration 108 - MAPE: 0.10%, MSE: 6.4199, MAE: 2.0021
# Iteration 109 - MAPE: 0.10%, MSE: 6.3881, MAE: 1.9967
# Iteration 110 - MAPE: 0.10%, MSE: 6.3567, MAE: 1.9912
# Iteration 111 - MAPE: 0.10%, MSE: 6.3257, MAE: 1.9859
# Iteration 112 - MAPE: 0.10%, MSE: 6.2951, MAE: 1.9811
# Iteration 113 - MAPE: 0.10%, MSE: 6.2650, MAE: 1.9763
# Iteration 114 - MAPE: 0.10%, MSE: 6.2352, MAE: 1.9715
# Iteration 115 - MAPE: 0.10%, MSE: 6.2057, MAE: 1.9666
# Iteration 116 - MAPE: 0.10%, MSE: 6.1765, MAE: 1.9619
# Iteration 117 - MAPE: 0.10%, MSE: 6.1475, MAE: 1.9575
# Iteration 118 - MAPE: 0.10%, MSE: 6.1191, MAE: 1.9533
# Iteration 119 - MAPE: 0.10%, MSE: 6.0908, MAE: 1.9491
# Iteration 120 - MAPE: 0.10%, MSE: 6.0630, MAE: 1.9448
# Iteration 121 - MAPE: 0.10%, MSE: 6.0354, MAE: 1.9405
# Iteration 122 - MAPE: 0.10%, MSE: 6.0081, MAE: 1.9363
# Iteration 123 - MAPE: 0.10%, MSE: 5.9810, MAE: 1.9320
# Iteration 124 - MAPE: 0.10%, MSE: 5.9542, MAE: 1.9280
# Iteration 125 - MAPE: 0.10%, MSE: 5.9281, MAE: 1.9243
# Iteration 126 - MAPE: 0.10%, MSE: 5.9025, MAE: 1.9209
# Iteration 127 - MAPE: 0.09%, MSE: 5.8774, MAE: 1.9173
# Iteration 128 - MAPE: 0.09%, MSE: 5.8527, MAE: 1.9137
# Iteration 129 - MAPE: 0.09%, MSE: 5.8283, MAE: 1.9103
# Iteration 130 - MAPE: 0.09%, MSE: 5.8042, MAE: 1.9071
# Iteration 131 - MAPE: 0.09%, MSE: 5.7804, MAE: 1.9039
# Iteration 132 - MAPE: 0.09%, MSE: 5.7568, MAE: 1.9008
# Iteration 133 - MAPE: 0.09%, MSE: 5.7333, MAE: 1.8977
# Iteration 134 - MAPE: 0.09%, MSE: 5.7101, MAE: 1.8946
# Iteration 135 - MAPE: 0.09%, MSE: 5.6871, MAE: 1.8912
# Iteration 136 - MAPE: 0.09%, MSE: 5.6641, MAE: 1.8877
# Iteration 137 - MAPE: 0.09%, MSE: 5.6413, MAE: 1.8842
# Iteration 138 - MAPE: 0.09%, MSE: 5.6186, MAE: 1.8806
# Iteration 139 - MAPE: 0.09%, MSE: 5.5958, MAE: 1.8769
# Iteration 140 - MAPE: 0.09%, MSE: 5.5732, MAE: 1.8735
# Iteration 141 - MAPE: 0.09%, MSE: 5.5506, MAE: 1.8703
# Iteration 142 - MAPE: 0.09%, MSE: 5.5281, MAE: 1.8668
# Iteration 143 - MAPE: 0.09%, MSE: 5.5060, MAE: 1.8631
# Iteration 144 - MAPE: 0.09%, MSE: 5.4841, MAE: 1.8595
# Iteration 145 - MAPE: 0.09%, MSE: 5.4625, MAE: 1.8556
# Iteration 146 - MAPE: 0.09%, MSE: 5.4411, MAE: 1.8515
# Iteration 147 - MAPE: 0.09%, MSE: 5.4197, MAE: 1.8475
# Iteration 148 - MAPE: 0.09%, MSE: 5.3985, MAE: 1.8434
# Iteration 149 - MAPE: 0.09%, MSE: 5.3773, MAE: 1.8393
# Iteration 150 - MAPE: 0.09%, MSE: 5.3564, MAE: 1.8351
# Iteration 151 - MAPE: 0.09%, MSE: 5.3355, MAE: 1.8308
# Iteration 152 - MAPE: 0.09%, MSE: 5.3147, MAE: 1.8266
# Iteration 153 - MAPE: 0.09%, MSE: 5.2941, MAE: 1.8223
# Iteration 154 - MAPE: 0.09%, MSE: 5.2736, MAE: 1.8176
# Iteration 155 - MAPE: 0.09%, MSE: 5.2533, MAE: 1.8130
# Iteration 156 - MAPE: 0.09%, MSE: 5.2332, MAE: 1.8086
# Iteration 157 - MAPE: 0.09%, MSE: 5.2131, MAE: 1.8044
# Iteration 158 - MAPE: 0.09%, MSE: 5.1932, MAE: 1.8002
# Iteration 159 - MAPE: 0.09%, MSE: 5.1734, MAE: 1.7962
# Iteration 160 - MAPE: 0.09%, MSE: 5.1537, MAE: 1.7926
# Iteration 161 - MAPE: 0.09%, MSE: 5.1343, MAE: 1.7892
# Iteration 162 - MAPE: 0.09%, MSE: 5.1149, MAE: 1.7857
# Iteration 163 - MAPE: 0.09%, MSE: 5.0959, MAE: 1.7826
# Iteration 164 - MAPE: 0.09%, MSE: 5.0771, MAE: 1.7794
# Iteration 165 - MAPE: 0.09%, MSE: 5.0585, MAE: 1.7764
# Iteration 166 - MAPE: 0.09%, MSE: 5.0399, MAE: 1.7731
# Iteration 167 - MAPE: 0.09%, MSE: 5.0213, MAE: 1.7698
# Iteration 168 - MAPE: 0.09%, MSE: 5.0026, MAE: 1.7668
# Iteration 169 - MAPE: 0.09%, MSE: 4.9838, MAE: 1.7638
# Iteration 170 - MAPE: 0.09%, MSE: 4.9651, MAE: 1.7610
# Iteration 171 - MAPE: 0.09%, MSE: 4.9465, MAE: 1.7581
# Iteration 172 - MAPE: 0.09%, MSE: 4.9280, MAE: 1.7552
# Iteration 173 - MAPE: 0.09%, MSE: 4.9096, MAE: 1.7522
# Iteration 174 - MAPE: 0.09%, MSE: 4.8914, MAE: 1.7492
# Iteration 175 - MAPE: 0.09%, MSE: 4.8732, MAE: 1.7464
# Iteration 176 - MAPE: 0.09%, MSE: 4.8552, MAE: 1.7436
# Iteration 177 - MAPE: 0.09%, MSE: 4.8372, MAE: 1.7407
# Iteration 178 - MAPE: 0.09%, MSE: 4.8192, MAE: 1.7378
# Iteration 179 - MAPE: 0.09%, MSE: 4.8014, MAE: 1.7350
# Iteration 180 - MAPE: 0.09%, MSE: 4.7837, MAE: 1.7322
# Iteration 181 - MAPE: 0.09%, MSE: 4.7661, MAE: 1.7292
# Iteration 182 - MAPE: 0.09%, MSE: 4.7486, MAE: 1.7262
# Iteration 183 - MAPE: 0.09%, MSE: 4.7313, MAE: 1.7231
# Iteration 184 - MAPE: 0.09%, MSE: 4.7141, MAE: 1.7199
# Iteration 185 - MAPE: 0.09%, MSE: 4.6972, MAE: 1.7170
# Iteration 186 - MAPE: 0.09%, MSE: 4.6805, MAE: 1.7140
# Iteration 187 - MAPE: 0.08%, MSE: 4.6639, MAE: 1.7110
# Iteration 188 - MAPE: 0.08%, MSE: 4.6474, MAE: 1.7080
# Iteration 189 - MAPE: 0.08%, MSE: 4.6309, MAE: 1.7051
# Iteration 190 - MAPE: 0.08%, MSE: 4.6145, MAE: 1.7022
# Iteration 191 - MAPE: 0.08%, MSE: 4.5982, MAE: 1.6994
# Iteration 192 - MAPE: 0.08%, MSE: 4.5821, MAE: 1.6965
# Iteration 193 - MAPE: 0.08%, MSE: 4.5661, MAE: 1.6935
# Iteration 194 - MAPE: 0.08%, MSE: 4.5503, MAE: 1.6907
# Iteration 195 - MAPE: 0.08%, MSE: 4.5345, MAE: 1.6883
# Iteration 196 - MAPE: 0.08%, MSE: 4.5190, MAE: 1.6857
# Iteration 197 - MAPE: 0.08%, MSE: 4.5036, MAE: 1.6829
# Iteration 198 - MAPE: 0.08%, MSE: 4.4884, MAE: 1.6799
# Iteration 199 - MAPE: 0.08%, MSE: 4.4732, MAE: 1.6771
# Iteration 200 - MAPE: 0.08%, MSE: 4.4581, MAE: 1.6742
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.67652994e+00
#  8.04179324e-03 0.00000000e+00]
# Weights saved to /content/drive/MyDrive/Sparse_PUFs/CD_final_weights.txt
# <Axes: xlabel='iters', ylabel='cost'>

# %%
# Calculate predictions on the validation set
y_pred_val = X_val.dot(w_cd_ols)
print(w_cd_ols)
mse_val = np.mean((y_val - y_pred_val)**2)

print("MSE on Validation Set:", mse_val)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.67652994e+00
#  8.04179324e-03 0.00000000e+00]
# MSE on Validation Set: 63.20850155104902

# %%
r_square = r_squared(y_val, y_pred_val)
print(f"r_square: {r_square:.4f}")
# Out:
# r_square: 0.9950
